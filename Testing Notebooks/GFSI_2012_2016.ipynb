# %% [markdown]
# # GFSI Data cleaning and saving for years 2012-2016

# %%
import pandas as pd
import glob

# %%
path = '../../GFSI'
allFiles = glob.glob(path + "/*.csv")
frame = pd.DataFrame()
GFSI_dfs = []
for file_ in allFiles:
    df = pd.read_csv(file_,index_col=None, header=None)
    GFSI_dfs.append(df)

# %%
for i in range(len(GFSI_dfs)):
    GFSI_dfs[i][0] = GFSI_dfs[i][0] + ' ' + GFSI_dfs[i][1]
    GFSI_dfs[i].drop(1, axis=1, inplace=True)
    GFSI_dfs[i] = GFSI_dfs[i].T
    GFSI_dfs[i] = GFSI_dfs[i].dropna(axis=1, how='all')
    new_header = GFSI_dfs[i].iloc[0]
    GFSI_dfs[i] = GFSI_dfs[i][1:]
    GFSI_dfs[i].rename(columns = new_header, inplace=True)
    GFSI_dfs[i]['1.3) Gross domestic product per capita (US$ PPP) US$ at PPP / capita'] = GFSI_dfs[i]['1.3) Gross domestic product per capita (US$ PPP) US$ at PPP / capita'].apply(lambda x: x.replace(',', ''))
    GFSI_dfs[i]['2.1.1) Average food supply kcal/capita/day'] = GFSI_dfs[i]['2.1.1) Average food supply kcal/capita/day'].apply(lambda x: x.replace(',', ''))
    pd.to_numeric(GFSI_dfs[i]['1.1) Food consumption as a share of household expenditure % of total household expenditure']).mean()
    GFSI_dfs[i].ix[:, GFSI_dfs[i].columns != 'Metric Desc'] = GFSI_dfs[i].ix[:, GFSI_dfs[i].columns != 'Metric Desc'].apply(lambda x: x.replace('n/a', None))
    GFSI_dfs[i].ix[:, GFSI_dfs[i].columns != 'Metric Desc'] = GFSI_dfs[i].ix[:, GFSI_dfs[i].columns != 'Metric Desc'].apply(pd.to_numeric)
    GFSI_dfs[i].to_csv('../Data/food_security_index_201{}'.format(str(i + 2)))

# %% [markdown]
# # Don't execute below code

# %%
GFSI = pd.read_csv('../../GFSI_2012.csv', header=None)

# %%
GFSI[0] = GFSI[0] + ' ' + GFSI[1]
GFSI.drop(1, axis=1, inplace=True)

# %%
GFSI = GFSI.T

# %%
GFSI = GFSI.dropna(axis=1, how='all')

# %%
new_header = GFSI.iloc[0]
GFSI = GFSI[1:]
GFSI.rename(columns = new_header, inplace=True)
GFSI.head()
# Out:
#   Metric Desc  \
# 2     Algeria
# 3      Angola
# 4   Argentina
# 5   Australia
# 6     Austria
#
#   1.1) Food consumption as a share of household expenditure % of total household expenditure  \
# 2                                               43.1
# 3                                               50.5
# 4                                               33.2
# 5                                               10.1
# 6                                                9.9
#
#   1.2) Proportion of population under global poverty line % of population living under $3.10/day 2011 PPP  \
# 2                                                8.4
# 3                                               54.5
# 4                                                3.6
# 5                                                0.0
# 6                                                0.0
#
#   1.3) Gross domestic product per capita (US$ PPP) US$ at PPP / capita  \
# 2                                             13,033
# 3                                              6,950
# 4                                             21,065
# 5                                             42,806
# 6                                             43,752
#
#   1.4) Agricultural import tariffs %  \
# 2                               23.3
# 3                               10.0
# 4                               10.3
# 5                                1.3
# 6                               12.8
#
#   1.5) Presence of food safety net programmes Qualitative assessment (0-4)  \
# 2                                                  2
# 3                                                  1
# 4                                                  3
# 5                                                  4
# 6                                                  4
#
#   1.6) Access to financing for farmers Qualitative assessment (0-4)  \
# 2                                                  1
# 3                                                  1
# 4                                                  3
# 5                                                  4
# 6                                                  4
#
#   2.1.1) Average food supply kcal/capita/day  \
# 2                                      3,153
# 3                                      1,973
# 4                                      2,941
# 5                                      3,227
# 6                                      3,819
#
#   2.1.2) Dependency on chronic food aid Qualitative assessment (0-2)  \
# 2                                                  1
# 3                                                  1
# 4                                                  2
# 5                                                  2
# 6                                                  2
#
#   2.2) Public expenditure on agricultural R&D Rating 1-9  \
# 2                                                  2
# 3                                                  2
# 4                                                  3
# 5                                                  3
# 6                                                  3
#
#               ...               \
# 2             ...
# 3             ...
# 4             ...
# 5             ...
# 6             ...
#
#   3.5.2) Percentage of population with access to potable water %  \
# 2                                               85.3
# 3                                               47.5
# 4                                               98.4
# 5                                              100.0
# 6                                              100.0
#
#   3.5.3) Presence of formal grocery sector Qualitative assessment (0-2)  \
# 2                                                  1
# 3                                                  0
# 4                                                  2
# 5                                                  2
# 6                                                  2
#
#   4.1) Prevalence of undernourishment %  \
# 2                                   5.0
# 3                                  41.0
# 4                                   7.0
# 5                                   5.0
# 6                                   5.0
#
#   4.2.1) Percentage of children stunted %  \
# 2                                    15.9
# 3                                    29.2
# 4                                     8.2
# 5                                     0.0
# 6                                     2.5
#
#   4.2.2) Percentage of children underweight %  \
# 2                                         3.7
# 3                                        15.6
# 4                                         2.3
# 5                                         0.0
# 6                                         1.2
#
#   4.3) Intensity of food deprivation kcal/person/day  \
# 2                                                 26
# 3                                                111
# 4                                                  8
# 5                                                  8
# 6                                                  8
#
#   4.4) Human Development Index Rating 0-1  \
# 2                                   0.698
# 3                                   0.486
# 4                                   0.797
# 5                                   0.929
# 6                                   0.885
#
#   4.5) Global Gender Gap Index Rating 0-1  \
# 2                                   0.599
# 3                                     n/a
# 4                                   0.724
# 5                                   0.729
# 6                                   0.717
#
#   4.6) EIU Democracy Index Rating 1-10; 10=most democratic  \
# 2                                                3.3
# 3                                                3.3
# 4                                                6.8
# 5                                                9.2
# 6                                                8.5
#
#   4.7) Prevalence of Obesity %
# 2                         22.6
# 3                          8.3
# 4                         23.7
# 5                         26.0
# 6                         16.7
#
# [5 rows x 37 columns]

# %%
GFSI['1.3) Gross domestic product per capita (US$ PPP) US$ at PPP / capita'] = GFSI['1.3) Gross domestic product per capita (US$ PPP) US$ at PPP / capita'].apply(lambda x: x.replace(',', ''))

# %%
GFSI['2.1.1) Average food supply kcal/capita/day'] = GFSI['2.1.1) Average food supply kcal/capita/day'].apply(lambda x: x.replace(',', ''))

# %%
GFSI.head()
# Out:
#   Metric Desc  \
# 2     Algeria
# 3      Angola
# 4   Argentina
# 5   Australia
# 6     Austria
#
#   1.1) Food consumption as a share of household expenditure % of total household expenditure  \
# 2                                               43.1
# 3                                               50.5
# 4                                               33.2
# 5                                               10.1
# 6                                                9.9
#
#   1.2) Proportion of population under global poverty line % of population living under $3.10/day 2011 PPP  \
# 2                                                8.4
# 3                                               54.5
# 4                                                3.6
# 5                                                0.0
# 6                                                0.0
#
#   1.3) Gross domestic product per capita (US$ PPP) US$ at PPP / capita  \
# 2                                              13033
# 3                                               6950
# 4                                              21065
# 5                                              42806
# 6                                              43752
#
#   1.4) Agricultural import tariffs %  \
# 2                               23.3
# 3                               10.0
# 4                               10.3
# 5                                1.3
# 6                               12.8
#
#   1.5) Presence of food safety net programmes Qualitative assessment (0-4)  \
# 2                                                  2
# 3                                                  1
# 4                                                  3
# 5                                                  4
# 6                                                  4
#
#   1.6) Access to financing for farmers Qualitative assessment (0-4)  \
# 2                                                  1
# 3                                                  1
# 4                                                  3
# 5                                                  4
# 6                                                  4
#
#   2.1.1) Average food supply kcal/capita/day  \
# 2                                       3153
# 3                                       1973
# 4                                       2941
# 5                                       3227
# 6                                       3819
#
#   2.1.2) Dependency on chronic food aid Qualitative assessment (0-2)  \
# 2                                                  1
# 3                                                  1
# 4                                                  2
# 5                                                  2
# 6                                                  2
#
#   2.2) Public expenditure on agricultural R&D Rating 1-9  \
# 2                                                  2
# 3                                                  2
# 4                                                  3
# 5                                                  3
# 6                                                  3
#
#               ...               \
# 2             ...
# 3             ...
# 4             ...
# 5             ...
# 6             ...
#
#   3.5.2) Percentage of population with access to potable water %  \
# 2                                               85.3
# 3                                               47.5
# 4                                               98.4
# 5                                              100.0
# 6                                              100.0
#
#   3.5.3) Presence of formal grocery sector Qualitative assessment (0-2)  \
# 2                                                  1
# 3                                                  0
# 4                                                  2
# 5                                                  2
# 6                                                  2
#
#   4.1) Prevalence of undernourishment %  \
# 2                                   5.0
# 3                                  41.0
# 4                                   7.0
# 5                                   5.0
# 6                                   5.0
#
#   4.2.1) Percentage of children stunted %  \
# 2                                    15.9
# 3                                    29.2
# 4                                     8.2
# 5                                     0.0
# 6                                     2.5
#
#   4.2.2) Percentage of children underweight %  \
# 2                                         3.7
# 3                                        15.6
# 4                                         2.3
# 5                                         0.0
# 6                                         1.2
#
#   4.3) Intensity of food deprivation kcal/person/day  \
# 2                                                 26
# 3                                                111
# 4                                                  8
# 5                                                  8
# 6                                                  8
#
#   4.4) Human Development Index Rating 0-1  \
# 2                                   0.698
# 3                                   0.486
# 4                                   0.797
# 5                                   0.929
# 6                                   0.885
#
#   4.5) Global Gender Gap Index Rating 0-1  \
# 2                                   0.599
# 3                                     n/a
# 4                                   0.724
# 5                                   0.729
# 6                                   0.717
#
#   4.6) EIU Democracy Index Rating 1-10; 10=most democratic  \
# 2                                                3.3
# 3                                                3.3
# 4                                                6.8
# 5                                                9.2
# 6                                                8.5
#
#   4.7) Prevalence of Obesity %
# 2                         22.6
# 3                          8.3
# 4                         23.7
# 5                         26.0
# 6                         16.7
#
# [5 rows x 37 columns]

# %%
pd.to_numeric(GFSI['1.1) Food consumption as a share of household expenditure % of total household expenditure']).mean()
# Out:
# 29.88495575221239

# %%
GFSI.ix[:, GFSI.columns != 'Metric Desc'] = GFSI.ix[:, GFSI.columns != 'Metric Desc'].apply(lambda x: x.replace('n/a', None))

# %%
GFSI.ix[:, GFSI.columns != 'Metric Desc'] = GFSI.ix[:, GFSI.columns != 'Metric Desc'].apply(pd.to_numeric)

# %%
GFSI.tail()
# Out:
#     Metric Desc  \
# 110  Uzbekistan
# 111   Venezuela
# 112     Vietnam
# 113       Yemen
# 114      Zambia
#
#     1.1) Food consumption as a share of household expenditure % of total household expenditure  \
# 110                                               58.1
# 111                                               32.2
# 112                                               39.9
# 113                                                 44
# 114                                               53.5
#
#     1.2) Proportion of population under global poverty line % of population living under $3.10/day 2011 PPP  \
# 110                                               17.7
# 111                                               14.9
# 112                                               18.1
# 113                                               12.7
# 114                                               78.9
#
#     1.3) Gross domestic product per capita (US$ PPP) US$ at PPP / capita  \
# 110                                               4413
# 111                                              17230
# 112                                               4639
# 113                                               3761
# 114                                               3556
#
#     1.4) Agricultural import tariffs %  \
# 110                               18.9
# 111                                 15
# 112                               17.8
# 113                               10.5
# 114                                 19
#
#     1.5) Presence of food safety net programmes Qualitative assessment (0-4)  \
# 110                                                  2
# 111                                                  3
# 112                                                  2
# 113                                                  0
# 114                                                  1
#
#     1.6) Access to financing for farmers Qualitative assessment (0-4)  \
# 110                                                  2
# 111                                                  3
# 112                                                  3
# 113                                                  1
# 114                                                  1
#
#     2.1.1) Average food supply kcal/capita/day  \
# 110                                       2581
# 111                                       2632
# 112                                       2816
# 113                                       2068
# 114                                       1873
#
#     2.1.2) Dependency on chronic food aid Qualitative assessment (0-2)  \
# 110                                                  2
# 111                                                  2
# 112                                                  2
# 113                                                  1
# 114                                                  1
#
#     2.2) Public expenditure on agricultural R&D Rating 1-9  \
# 110                                                  1
# 111                                                  4
# 112                                                  1
# 113                                                  1
# 114                                                  1
#
#                 ...               \
# 110             ...
# 111             ...
# 112             ...
# 113             ...
# 114             ...
#
#     3.5.2) Percentage of population with access to potable water %  \
# 110                                               87.3
# 111                                               92.8
# 112                                               92.6
# 113                                               54.7
# 114                                               62.2
#
#     3.5.3) Presence of formal grocery sector Qualitative assessment (0-2)  \
# 110                                                  2
# 111                                                  1
# 112                                                  1
# 113                                                  0
# 114                                                  0
#
#     4.1) Prevalence of undernourishment %  \
# 110                                    11
# 111                                     7
# 112                                    11
# 113                                    30
# 114                                    44
#
#     4.2.1) Percentage of children stunted %  \
# 110                                    19.6
# 111                                    15.6
# 112                                    30.5
# 113                                    57.7
# 114                                    42.9
#
#     4.2.2) Percentage of children underweight %  \
# 110                                         4.4
# 111                                         3.7
# 112                                        20.2
# 113                                        43.1
# 114                                        14.9
#
#     4.3) Intensity of food deprivation kcal/person/day  \
# 110                                                 45
# 111                                                 12
# 112                                                 99
# 113                                                177
# 114                                                421
#
#     4.4) Human Development Index Rating 0-1  \
# 110                                   0.641
# 111                                   0.735
# 112                                   0.593
# 113                                   0.462
# 114                                    0.43
#
#     4.5) Global Gender Gap Index Rating 0-1  \
# 110                                   0.691
# 111                                   0.686
# 112                                   0.673
# 113                                   0.487
# 114                                    0.63
#
#     4.6) EIU Democracy Index Rating 1-10; 10=most democratic  \
# 110                                                1.7
# 111                                                5.2
# 112                                                2.9
# 113                                                2.6
# 114                                                5.7
#
#     4.7) Prevalence of Obesity %
# 110                         13.6
# 111                         23.3
# 112                          2.6
# 113                         15.7
# 114                          7.1
#
# [5 rows x 37 columns]

# %%
GFSI.to_csv('../Data/food_security_index_2012')
