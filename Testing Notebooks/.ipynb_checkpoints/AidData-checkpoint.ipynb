# %%
import requests

# %%
url = 'http://api.aiddata.org/aid/project'

Filters = {
    'src' :'1,2,3,4,5,6,7,3249668',
    'from' : '0',
    'size' : '50'
}

# %%
r = requests.get(url, params=Filters)

# %%
r.json()
# Out:
# {'items': [{'contributions': 0,
#    'long_description': 'Provide financial resources to ETI for medium-to-long term project finance and to finance capital equipment, including permanent working capital required to create new production capacities and increase the capacity utilization of existing facilities.',
#    'organisations': [{'org_id': 1,
#      'org_name': 'African Development Bank (AFDB)',
#      'org_role_id': 3,
#      'org_role_name': 'Funding'}],
#    'project_id': 1,
#    'sectors3': [{'_id': 111,
#      'code': '240',
#      'name': 'BANKING AND FINANCIAL SERVICES'}],
#    'sectors5': [{'_id': 116,
#      'code': '24030',
#      'name': 'Formal sector financial intermediaries'}],
#    'sectors7': [{'_id': 1820,
#      'code': '24030.02',
#      'name': 'All formal sector financial intermediaries'},
#     {'_id': 1821, 'code': '24030.03', 'name': 'Credit lines'}],
#    'source': {'_id': 1, 'key': 'annual-report', 'label': 'Annual Report'},
# ...

# %%
data = r.json()

# %%
data.keys()
# Out:
# dict_keys(['stats', 'items', 'project_count'])

# %%
data['stats']
# Out:
# {'_type': 'statistical',
#  'count': 2998788,
#  'max': 7435523047779259,
#  'mean': 33559187580.301876,
#  'min': -1664224304.1045797,
#  'std_deviation': 7331820698000.942,
#  'sum_of_squares': 1.6120500975430658e+32,
#  'total': 100636889005558300,
#  'variance': 5.375559474763502e+25}

# %%
data['project_count']
# Out:
# 1801387
