# %% [markdown]
# # Unicef Data
# - children assumed to by under 5 years of age
#
# ### Malnutrition
# - Severe Wasting: Percentage of children aged 0–59 months who are below minus three standard deviations from median weight-for-height of the WHO Child Growth Standards.
# - Wasting – Moderate and severe: Percentage of children aged 0–59 months who are below minus two standard deviations from median weight-for-height of the WHO Child Growth Standards.
# - Overweight – Moderate and severe: Percentage of children aged 0-59 months who are above two standard deviations from median weight-for-height of the WHO Child Growth Standards.
# - Stunting – Moderate and severe: Percentage of children aged 0–59 months who are below minus two standard deviations from median height-for-age of the WHO Child Growth Standards.
# - Underweight – Moderate and severe: Percentage of children aged 0–59 months who are below minus two standard deviations from median weight-for-age of the World Health Organization (WHO) Child Growth Standards.
#
# ### Stunting
# - percentages in terms of total child population

# %%
import pandas as pd

# %%
pd.read_csv?

# %%
malnutrition = pd.read_csv('../UNICEF_child_malnutrition_dec_2016.csv', header=1)

# %%
malnutrition.head()
# Out:
#   ISO code      Country Survey year  Year united_nations_subregion  \
# 0      AFG  AFGHANISTAN        1997  1997                 SOUTHASI
# 1      AFG  AFGHANISTAN        2004  2004                 SOUTHASI
# 2      AFG  AFGHANISTAN        2013  2013                 SOUTHASI
# 3      ALB      ALBANIA     1996-98  1997                 SOUTHEUR
# 4      ALB      ALBANIA        2000  2000                 SOUTHEUR
#
#   united_nations_region Millenium Development Goals  UNICEF  \
# 0                  ASIA               Southern Asia    ROSA
# 1                  ASIA               Southern Asia    ROSA
# 2                  ASIA               Southern Asia    ROSA
# 3                EUROPE           Developed regions  CEECIS
# 4                EUROPE           Developed regions  CEECIS
#
#   World Health Organization world_bank_income_group     ...      \
# 0                      EMRO              Low income     ...
# 1                      EMRO              Low income     ...
# 2                      EMRO              Low income     ...
# 3                      EURO     Upper middle income     ...
# 4                      EURO     Upper middle income     ...
#
#   Severe wasting Wasting  Overweight  Stunting  Underweight  \
# 0            NaN    18.2         6.5      53.2         44.9
# 1            3.5     8.6         4.6      59.3         32.9
# 2            4.0     9.5         5.4      40.9         25.0
# 3            NaN     8.1         9.5      20.4          7.1
# 4            6.2    12.2          30      39.2         17.0
#
#                   Notes                                      Report Author  \
# 0   Converted estimates                                                NaN
# 1                   NaN  Ministry of Public Health (Afghanistan), UNICE...
# 2  (pending reanalysis)  Ministry of Public Health, UNICEF and the Aga ...
# 3   Converted estimates                                                NaN
# 4                   NaN  National Institute of Statistics (Albania) and...
#
#                                               Source  \
# 0  Afghanistan 1997 multiple indicator baseline (...
# 1  Summary report of the national nutrition surve...
# 2        Afghanistan National Nutrition Survey 2013.
# 3  National study on nutrition in Albania. Instit...
# 4  Multiple indicator cluster survey report Alban...
#
#   Under 5 population (000s) Unnamed: 22
# 0                  3567.351         NaN
# 1                  4551.391         NaN
# 2                  4993.944         NaN
# 3                   307.871         NaN
# 4                   278.754         NaN
#
# [5 rows x 23 columns]

# %%
stunting_area = pd.read_csv('../UNICEF_stunting_prevalence_by_area_residence_09_15.csv').dropna()

# %%
stunting_area.head()
# Out:
#    country_code     country  urban  rural  ratio_rural_to_\nurban  \
# 1           ALB     Albania   20.0   19.0                     1.0
# 2           DZA     Algeria   11.0   12.0                     1.1
# 4           AGO      Angola   30.0   33.0                     1.1
# 7           ARM     Armenia   17.0   22.0                     1.3
# 10          AZE  Azerbaijan   15.0   21.0                     1.4
#
#    reference_year                      data_source
# 1         2008–09                   DHS, 2008–2009
# 2         2012-13                    MICS, 2012-13
# 4            2007                   Other NS, 2007
# 7            2010                        DHS, 2010
# 10           2013  National Nutrition Survey, 2013

# %%
stunting_wealth = pd.read_csv('../UNICEF_stunting_prevalence_children_by_wealth_quintile_09_15.csv').dropna()

# %%
stunting_wealth.head()
# Out:
#    country_code      country   WQ1   WQ5  ratio_poorest_to_richest  \
# 0           AFG  Afghanistan  49.0  31.0                       1.6
# 1           ALB      Albania  27.0  13.0                       2.1
# 2           DZA      Algeria  13.0  11.0                       1.2
# 7           ARM      Armenia  26.0  19.0                       1.4
# 10          AZE   Azerbaijan  28.0  16.0                       1.8
#
#    reference_year                      data_source
# 0            2013                    Other NS 2013
# 1         2008–09                   DHS, 2008–2009
# 2         2012-13                    MICS, 2012-13
# 7            2010                        DHS, 2010
# 10           2013  National Nutrition Survey, 2013
