# %% [markdown]
# ### following data are of as 2012
#
# Seemed like there was access to later years data in the original file, but couldn't access with Mac Numbers. Should explore more with Excel

# %%
import pandas as pd

# %%
GFSI = pd.DataFrame.from_csv('../GFSI_2012.csv', index_col=None)

# %%
GFSI.head()
# Out:
#                                               Metric  \
# 0  1.1) Food consumption as a share of household ...
# 1  1.2) Proportion of population under global pov...
# 2   1.3) Gross domestic product per capita (US$ PPP)
# 3                   1.4) Agricultural import tariffs
# 4        1.5) Presence of food safety net programmes
#
#                                               Desc Algeria Angola Argentina  \
# 0                 % of total household expenditure    43.1   50.5      33.2
# 1  % of population living under $3.10/day 2011 PPP     8.4   54.5       3.6
# 2                              US$ at PPP / capita  13,033  6,950    21,065
# 3                                                %    23.3   10.0      10.3
# 4                     Qualitative assessment (0-4)       2      1         3
#
#   Australia Austria Azerbaijan Bahrain Bangladesh  ...   Ukraine  \
# 0      10.1     9.9       43.1    15.7       53.8  ...      38.2
# ...
